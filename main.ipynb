# %%
from utils.get_stock_info import get_stock_info
from utils.get_today_price_movement import get_today_price_movement
from utils.plot_today_price_movement import plot_today_price_movement
from utils.print_stock_info import print_stock_info

# Define stock symbol
chosenStock = "mcd"

try:
    stock_info = get_stock_info(chosenStock)
    print_stock_info(stock_info)

    intraday_close = get_today_price_movement(chosenStock)
    plot_today_price_movement(chosenStock, intraday_close)
except Exception as e:
    print(f"Error: {e}")
# Out:
# ============================
# MCDONALD'S CORPORATION (MCD)
# ============================
# Current Price: 329.45
# Open: 328.45 | High: 332.95 | Low: 326.95
# Market Cap: 235.09B
# P/E Ratio: 27.59
# 52 Week High: 335.67 | 52 Week Low: 283.47
# Dividend: 7.44
# Dividend Yield %: 2.25
# Qtrly Div Amt: 1.86
#
#
# Data collected on: 2026-02-19 22:10:34
